# %% [markdown]
# <a href="https://colab.research.google.com/github/flyingrockingit/Module-10/blob/main/Visualization_with_Data_Science_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files = files.upload ()
# Out:
#      <input type="file" id="files-c1cdef74-f0b1-4555-ba73-4838db8e3758" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1cdef74-f0b1-4555-ba73-4838db8e3758">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('Countries Data.csv')
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
c_52=df.loc[df['year']==1952]
c_52.head()
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# 24      Algeria  1952     9279525    Africa    43.077  2449.008185
# 36       Angola  1952     4232095    Africa    30.015  3520.610273
# 48    Argentina  1952    17876956  Americas    62.485  5911.315053

# %%
c_07=df.loc[df['year']==2007]
c_07.head()
# Out:
#         country  year  population continent  life_exp       gdp_cap
# 11  Afghanistan  2007    31889923      Asia    43.828    974.580338
# 23      Albania  2007     3600523    Europe    76.423   5937.029526
# 35      Algeria  2007    33333216    Africa    72.301   6223.367465
# 47       Angola  2007    12420476    Africa    42.731   4797.231267
# 59    Argentina  2007    40301927  Americas    75.320  12779.379640

# %%
c_merge = c_52.merge(c_07,left_on='country', right_on='country')
c_merge.head()
# Out:
#        country  year_x  population_x continent_x  life_exp_x    gdp_cap_x  \
# 0  Afghanistan    1952       8425333        Asia      28.801   779.445314
# 1      Albania    1952       1282697      Europe      55.230  1601.056136
# 2      Algeria    1952       9279525      Africa      43.077  2449.008185
# 3       Angola    1952       4232095      Africa      30.015  3520.610273
# 4    Argentina    1952      17876956    Americas      62.485  5911.315053
#
#    year_y  population_y continent_y  life_exp_y     gdp_cap_y
# 0    2007      31889923        Asia      43.828    974.580338
# 1    2007       3600523      Europe      76.423   5937.029526
# 2    2007      33333216      Africa      72.301   6223.367465
# 3    2007      12420476      Africa      42.731   4797.231267
# 4    2007      40301927    Americas      75.320  12779.379640

# %%
c_merge = c_merge.drop(['year_x', 'year_y'], axis=1)

# %%
c_merge['population_growth'] = c_merge['population_y'] - c_merge['population_x']
c_merge.head()
# Out:
#        country  population_x continent_x  life_exp_x    gdp_cap_x  \
# 0  Afghanistan       8425333        Asia      28.801   779.445314
# 1      Albania       1282697      Europe      55.230  1601.056136
# 2      Algeria       9279525      Africa      43.077  2449.008185
# 3       Angola       4232095      Africa      30.015  3520.610273
# 4    Argentina      17876956    Americas      62.485  5911.315053
#
#    population_y continent_y  life_exp_y     gdp_cap_y  population_growth
# 0      31889923        Asia      43.828    974.580338           23464590
# 1       3600523      Europe      76.423   5937.029526            2317826
# 2      33333216      Africa      72.301   6223.367465           24053691
# 3      12420476      Africa      42.731   4797.231267            8188381
# 4      40301927    Americas      75.320  12779.379640           22424971

# %%
c_merge = c_merge.sort_values('population_growth', ascending=False)
c_merge.head()
# Out:
#            country  population_x continent_x  life_exp_x     gdp_cap_x  \
# 24           China     556263527        Asia      44.000    400.448611
# 58           India     372000000        Asia      37.373    546.565749
# 134  United States     157553000    Americas      68.440  13990.482080
# 59       Indonesia      82052000        Asia      37.468    749.681655
# 14          Brazil      56602560    Americas      50.917   2108.944355
#
#      population_y continent_y  life_exp_y     gdp_cap_y  population_growth
# 24     1318683096        Asia      72.961   4959.114854          762419569
# 58     1110396331        Asia      64.698   2452.210407          738396331
# 134     301139947    Americas      78.242  42951.653090          143586947
# 59      223547000        Asia      70.650   3540.651564          141495000
# 14      190010647    Americas      72.390   9065.800825          133408087

# %%
c_merge = c_merge.reset_index(drop=True)
c_merge.head()
# Out:
#          country  population_x continent_x  life_exp_x     gdp_cap_x  \
# 0          China     556263527        Asia      44.000    400.448611
# 1          India     372000000        Asia      37.373    546.565749
# 2  United States     157553000    Americas      68.440  13990.482080
# 3      Indonesia      82052000        Asia      37.468    749.681655
# 4         Brazil      56602560    Americas      50.917   2108.944355
#
#    population_y continent_y  life_exp_y     gdp_cap_y  population_growth
# 0    1318683096        Asia      72.961   4959.114854          762419569
# 1    1110396331        Asia      64.698   2452.210407          738396331
# 2     301139947    Americas      78.242  42951.653090          143586947
# 3     223547000        Asia      70.650   3540.651564          141495000
# 4     190010647    Americas      72.390   9065.800825          133408087

# %%
c_merge.shape
# Out:
# (142, 10)

# %%
c_merge.head(10)
# Out:
#          country  population_x continent_x  life_exp_x     gdp_cap_x  \
# 0          China     556263527        Asia      44.000    400.448611
# 1          India     372000000        Asia      37.373    546.565749
# 2  United States     157553000    Americas      68.440  13990.482080
# 3      Indonesia      82052000        Asia      37.468    749.681655
# 4         Brazil      56602560    Americas      50.917   2108.944355
# 5       Pakistan      41346560        Asia      43.436    684.597144
# 6     Bangladesh      46886859        Asia      37.484    684.244172
# 7        Nigeria      33119096      Africa      36.324   1077.281856
# 8         Mexico      30144317    Americas      50.789   3478.125529
# 9    Philippines      22438691        Asia      47.752   1272.880995
#
#    population_y continent_y  life_exp_y     gdp_cap_y  population_growth
# 0    1318683096        Asia      72.961   4959.114854          762419569
# ...

# %%
countries = ['China', 'India','United States','Indonesia','Brazil','Pakistan','Bangladesh','Nigeria',"Mexico", 'Philippines']
population_growth = c_merge['population_growth'].head(10)
plt.figure(figsize=(12,6))
bars = plt.bar(countries, population_growth, color='skyblue', edgecolor='black')
plt.title('Population Growth (1952 → 2007) for Top 10 Countries', fontsize=16)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Population Growth', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
